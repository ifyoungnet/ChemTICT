# %% [markdown]
# # Dependency package import

# %%
from pycaret.classification import *
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ROCAUC
import matplotlib

# %% [markdown]
# # AP-XGBoost

# %%
df_train = pd.read_csv('../dataset/AtomPair_880.csv')
df_train.iloc[:,1:] = df_train.iloc[:,1:].astype(float)
df_train['Label'] = df_train['Label'].str.replace('TICT','1')
df_train['Label'] = df_train['Label'].str.replace('PICT','0')
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
df_train['Label'] = df_train['Label'].astype(int)

# %%
exp = setup(df_train,target='Label',train_size=0.8,numeric_features=features_train_,preprocess = False,silent=True,session_id=801,verbose=0)

# %%
xgboost = create_model('xgboost',fold=5)
# Out:
# <style type="text/css">
# #T_aad96_row5_col0, #T_aad96_row5_col1, #T_aad96_row5_col2, #T_aad96_row5_col3, #T_aad96_row5_col4, #T_aad96_row5_col5, #T_aad96_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_aad96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aad96_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_aad96_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_aad96_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_aad96_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_aad96_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_aad96_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_aad96_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aad96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aad96_row0_col0" class="data row0 col0" >0.7447</td>
#       <td id="T_aad96_row0_col1" class="data row0 col1" >0.8097</td>
#       <td id="T_aad96_row0_col2" class="data row0 col2" >0.8395</td>
#       <td id="T_aad96_row0_col3" class="data row0 col3" >0.7473</td>
#       <td id="T_aad96_row0_col4" class="data row0 col4" >0.7907</td>
#       <td id="T_aad96_row0_col5" class="data row0 col5" >0.4662</td>
#       <td id="T_aad96_row0_col6" class="data row0 col6" >0.4715</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aad96_row1_col0" class="data row1 col0" >0.7305</td>
#       <td id="T_aad96_row1_col1" class="data row1 col1" >0.7014</td>
#       <td id="T_aad96_row1_col2" class="data row1 col2" >0.8148</td>
#       <td id="T_aad96_row1_col3" class="data row1 col3" >0.7416</td>
#       <td id="T_aad96_row1_col4" class="data row1 col4" >0.7765</td>
#       <td id="T_aad96_row1_col5" class="data row1 col5" >0.4391</td>
#       <td id="T_aad96_row1_col6" class="data row1 col6" >0.4422</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aad96_row2_col0" class="data row2 col0" >0.7376</td>
#       <td id="T_aad96_row2_col1" class="data row2 col1" >0.7663</td>
#       <td id="T_aad96_row2_col2" class="data row2 col2" >0.8148</td>
#       <td id="T_aad96_row2_col3" class="data row2 col3" >0.7500</td>
#       <td id="T_aad96_row2_col4" class="data row2 col4" >0.7811</td>
#       <td id="T_aad96_row2_col5" class="data row2 col5" >0.4550</td>
#       <td id="T_aad96_row2_col6" class="data row2 col6" >0.4575</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aad96_row3_col0" class="data row3 col0" >0.6809</td>
#       <td id="T_aad96_row3_col1" class="data row3 col1" >0.6979</td>
#       <td id="T_aad96_row3_col2" class="data row3 col2" >0.7901</td>
#       <td id="T_aad96_row3_col3" class="data row3 col3" >0.6957</td>
#       <td id="T_aad96_row3_col4" class="data row3 col4" >0.7399</td>
#       <td id="T_aad96_row3_col5" class="data row3 col5" >0.3313</td>
#       <td id="T_aad96_row3_col6" class="data row3 col6" >0.3358</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aad96_row4_col0" class="data row4 col0" >0.7143</td>
#       <td id="T_aad96_row4_col1" class="data row4 col1" >0.7880</td>
#       <td id="T_aad96_row4_col2" class="data row4 col2" >0.7531</td>
#       <td id="T_aad96_row4_col3" class="data row4 col3" >0.7531</td>
#       <td id="T_aad96_row4_col4" class="data row4 col4" >0.7531</td>
#       <td id="T_aad96_row4_col5" class="data row4 col5" >0.4141</td>
#       <td id="T_aad96_row4_col6" class="data row4 col6" >0.4141</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_aad96_row5_col0" class="data row5 col0" >0.7216</td>
#       <td id="T_aad96_row5_col1" class="data row5 col1" >0.7527</td>
#       <td id="T_aad96_row5_col2" class="data row5 col2" >0.8025</td>
#       <td id="T_aad96_row5_col3" class="data row5 col3" >0.7375</td>
#       <td id="T_aad96_row5_col4" class="data row5 col4" >0.7682</td>
#       <td id="T_aad96_row5_col5" class="data row5 col5" >0.4212</td>
#       <td id="T_aad96_row5_col6" class="data row5 col6" >0.4242</td>
#     </tr>
#     <tr>
#       <th id="T_aad96_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_aad96_row6_col0" class="data row6 col0" >0.0227</td>
#       <td id="T_aad96_row6_col1" class="data row6 col1" >0.0454</td>
#       <td id="T_aad96_row6_col2" class="data row6 col2" >0.0292</td>
#       <td id="T_aad96_row6_col3" class="data row6 col3" >0.0213</td>
#       <td id="T_aad96_row6_col4" class="data row6 col4" >0.0188</td>
#       <td id="T_aad96_row6_col5" class="data row6 col5" >0.0482</td>
#       <td id="T_aad96_row6_col6" class="data row6 col6" >0.0481</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_prediction = predict_model(xgboost,raw_score=True)
# test_prediction.to_csv('AtomPairfinal_model_test.csv')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e11d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e11d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3e11d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3e11d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3e11d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3e11d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3e11d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3e11d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3e11d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e11d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e11d_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3e11d_row0_col1" class="data row0 col1" >0.7841</td>
#       <td id="T_3e11d_row0_col2" class="data row0 col2" >0.8460</td>
#       <td id="T_3e11d_row0_col3" class="data row0 col3" >0.7925</td>
#       <td id="T_3e11d_row0_col4" class="data row0 col4" >0.8400</td>
#       <td id="T_3e11d_row0_col5" class="data row0 col5" >0.8155</td>
#       <td id="T_3e11d_row0_col6" class="data row0 col6" >0.5558</td>
#       <td id="T_3e11d_row0_col7" class="data row0 col7" >0.5572</td>
#     </tr>
#   </tbody>
# </table>

# %%
X_train = get_config('X_train')
y_train = get_config('y_train')
X_test = get_config('X_test')
y_test = get_config('y_test')

# %%
final_model = finalize_model(xgboost)
# save_model(final_model, 'AtomPairfinal_model')

# %%
plt.figure(figsize=(6,6))
plt.xticks(fontfamily = 'Arial', fontsize=20)
plt.yticks(fontfamily = 'Arial', fontsize=20)
plt.xlabel(' ', fontfamily = 'Arial', fontsize=20)
plt.ylabel(' ', fontfamily = 'Arial', fontsize=20)
matplotlib.rc('font', family='Arial', weight='normal', size=16)
visualizer = ROCAUC(xgboost, title=' ')
visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
g = visualizer.poof()            # Draw/show/poof the data
# g.get_figure().savefig('AtomPair_ROCAUC.tiff',dpi=600)

# %% [markdown]
# # 2D+3D descriptors-CatBoost

# %%
df_train = pd.read_csv('../dataset/AM1_863.csv')
data_RFE = pd.read_csv('../dataset/AM1_RFE_ignore.csv')

# %%
rfe_ignore = list(data_RFE.columns)

# %%
df_train.iloc[:,1:] = df_train.iloc[:,1:].astype(float)
df_train['Label'] = df_train['Label'].str.replace('TICT','1')
df_train['Label'] = df_train['Label'].str.replace('PICT','0')
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
df_train['Label'] = df_train['Label'].astype(int)

# %%
exp = setup(df_train,target='Label',train_size=0.8,numeric_features=features_train_,ignore_features=rfe_ignore,
            silent = True,preprocess = False,session_id=8535,verbose=0)

# %%
cat = create_model('catboost',fold=5)
# Out:
# <style type="text/css">
# #T_d35c2_row5_col0, #T_d35c2_row5_col1, #T_d35c2_row5_col2, #T_d35c2_row5_col3, #T_d35c2_row5_col4, #T_d35c2_row5_col5, #T_d35c2_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d35c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d35c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d35c2_row0_col0" class="data row0 col0" >0.7391</td>
#       <td id="T_d35c2_row0_col1" class="data row0 col1" >0.8065</td>
#       <td id="T_d35c2_row0_col2" class="data row0 col2" >0.7895</td>
#       <td id="T_d35c2_row0_col3" class="data row0 col3" >0.7500</td>
#       <td id="T_d35c2_row0_col4" class="data row0 col4" >0.7692</td>
#       <td id="T_d35c2_row0_col5" class="data row0 col5" >0.4697</td>
#       <td id="T_d35c2_row0_col6" class="data row0 col6" >0.4705</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d35c2_row1_col0" class="data row1 col0" >0.7174</td>
#       <td id="T_d35c2_row1_col1" class="data row1 col1" >0.7736</td>
#       <td id="T_d35c2_row1_col2" class="data row1 col2" >0.7632</td>
#       <td id="T_d35c2_row1_col3" class="data row1 col3" >0.7342</td>
#       <td id="T_d35c2_row1_col4" class="data row1 col4" >0.7484</td>
#       <td id="T_d35c2_row1_col5" class="data row1 col5" >0.4263</td>
#       <td id="T_d35c2_row1_col6" class="data row1 col6" >0.4268</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d35c2_row2_col0" class="data row2 col0" >0.7319</td>
#       <td id="T_d35c2_row2_col1" class="data row2 col1" >0.7793</td>
#       <td id="T_d35c2_row2_col2" class="data row2 col2" >0.8158</td>
#       <td id="T_d35c2_row2_col3" class="data row2 col3" >0.7294</td>
#       <td id="T_d35c2_row2_col4" class="data row2 col4" >0.7702</td>
#       <td id="T_d35c2_row2_col5" class="data row2 col5" >0.4508</td>
#       <td id="T_d35c2_row2_col6" class="data row2 col6" >0.4549</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d35c2_row3_col0" class="data row3 col0" >0.7101</td>
#       <td id="T_d35c2_row3_col1" class="data row3 col1" >0.7666</td>
#       <td id="T_d35c2_row3_col2" class="data row3 col2" >0.8267</td>
#       <td id="T_d35c2_row3_col3" class="data row3 col3" >0.6966</td>
#       <td id="T_d35c2_row3_col4" class="data row3 col4" >0.7561</td>
#       <td id="T_d35c2_row3_col5" class="data row3 col5" >0.4053</td>
#       <td id="T_d35c2_row3_col6" class="data row3 col6" >0.4144</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d35c2_row4_col0" class="data row4 col0" >0.7101</td>
#       <td id="T_d35c2_row4_col1" class="data row4 col1" >0.7782</td>
#       <td id="T_d35c2_row4_col2" class="data row4 col2" >0.7467</td>
#       <td id="T_d35c2_row4_col3" class="data row4 col3" >0.7273</td>
#       <td id="T_d35c2_row4_col4" class="data row4 col4" >0.7368</td>
#       <td id="T_d35c2_row4_col5" class="data row4 col5" >0.4144</td>
#       <td id="T_d35c2_row4_col6" class="data row4 col6" >0.4146</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d35c2_row5_col0" class="data row5 col0" >0.7217</td>
#       <td id="T_d35c2_row5_col1" class="data row5 col1" >0.7808</td>
#       <td id="T_d35c2_row5_col2" class="data row5 col2" >0.7884</td>
#       <td id="T_d35c2_row5_col3" class="data row5 col3" >0.7275</td>
#       <td id="T_d35c2_row5_col4" class="data row5 col4" >0.7561</td>
#       <td id="T_d35c2_row5_col5" class="data row5 col5" >0.4333</td>
#       <td id="T_d35c2_row5_col6" class="data row5 col6" >0.4362</td>
#     </tr>
#     <tr>
#       <th id="T_d35c2_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d35c2_row6_col0" class="data row6 col0" >0.0118</td>
#       <td id="T_d35c2_row6_col1" class="data row6 col1" >0.0136</td>
#       <td id="T_d35c2_row6_col2" class="data row6 col2" >0.0303</td>
#       <td id="T_d35c2_row6_col3" class="data row6 col3" >0.0174</td>
#       <td id="T_d35c2_row6_col4" class="data row6 col4" >0.0127</td>
#       <td id="T_d35c2_row6_col5" class="data row6 col5" >0.0238</td>
#       <td id="T_d35c2_row6_col6" class="data row6 col6" >0.0226</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_prediction = predict_model(cat,raw_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_542dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_542dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_542dd_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_542dd_row0_col1" class="data row0 col1" >0.7399</td>
#       <td id="T_542dd_row0_col2" class="data row0 col2" >0.7633</td>
#       <td id="T_542dd_row0_col3" class="data row0 col3" >0.8218</td>
#       <td id="T_542dd_row0_col4" class="data row0 col4" >0.7545</td>
#       <td id="T_542dd_row0_col5" class="data row0 col5" >0.7867</td>
#       <td id="T_542dd_row0_col6" class="data row0 col6" >0.4549</td>
#       <td id="T_542dd_row0_col7" class="data row0 col7" >0.4577</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_fi = pd.DataFrame({'importance':cat.feature_importances_,'feature':list(features_train.drop(rfe_ignore,1))})
df_fi.sort_values('importance',ascending=False)
# Out:
#     importance       feature
# 61    3.380277  GCUT_SLOGP_0
# 33    3.102590     vsurf_CW2
# 93    2.737365    SlogP_VSA0
# 85    2.388271     Q_VSA_HYD
# 94    1.878880    SlogP_VSA5
# ..         ...           ...
# 42    0.408488     vsurf_HB3
# 1     0.403933        AM1_HF
# 20    0.390981        FCASA+
# 35    0.386775      vsurf_D3
# 8     0.282222         CASA-
#
# [104 rows x 2 columns]

# %%
explainer = shap.Explainer(cat)
shap_values = explainer.shap_values(test_prediction.iloc[:,:104])

# %%
shap_df = pd.DataFrame(shap_values)
shap_list = []
for i in list(range(0,104,1)):
#     print(i)
    influ = sum(np.abs(shap_df.iloc[:,i]))
    shap_list.append(influ)
df_shap = pd.DataFrame({'shap':shap_list,'feature':list(features_train.drop(rfe_ignore,1))})
df_shap.sort_values('shap',ascending=False)
# Out:
#          shap       feature
# 61  35.377820  GCUT_SLOGP_0
# 33  26.581532     vsurf_CW2
# 85  24.348574     Q_VSA_HYD
# 93  21.296454    SlogP_VSA0
# 37  16.014282    vsurf_DD23
# ..        ...           ...
# 42   1.351186     vsurf_HB3
# 51   1.289317     vsurf_IW4
# 16   1.282517         E_ele
# 35   1.217652      vsurf_D3
# 5    1.086510          ASA-
#
# [104 rows x 2 columns]

# %%
plt.xticks(fontfamily = 'Arial', fontsize=16)
plt.yticks(fontfamily = 'Arial', fontsize=16)
plt.xlabel(' ', fontfamily = 'Arial', fontsize=16)
plt.ylabel(' ', fontfamily = 'Arial', fontsize=16)

fig = plt.gcf()
plt.grid()
shap.summary_plot(shap_values, test_prediction.iloc[:,:104], max_display=20)
# fig.savefig('AM1_SHAP1.jpg',dpi=600,bbox_inches='tight')
plt.show()

# %% [markdown]
# # MACCS-CatBoost

# %%
df_train = pd.read_csv('../dataset/MACCS_880.csv')
df_train.iloc[:,1:] = df_train.iloc[:,1:].astype(float)
df_train['Label'] = df_train['Label'].str.replace('TICT','1')
df_train['Label'] = df_train['Label'].str.replace('PICT','0')
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
features_train = df_train.iloc[:,1:]
features_train_ = list(features_train)
df_train['Label'] = df_train['Label'].astype(int)

# %%
exp = setup(df_train,target='Label',train_size=0.8,numeric_features=features_train_,
            silent = True,preprocess = False,session_id=2290,verbose=0)

# %%
cat = create_model('catboost',fold=5)
# Out:
# <style type="text/css">
# #T_329b3_row5_col0, #T_329b3_row5_col1, #T_329b3_row5_col2, #T_329b3_row5_col3, #T_329b3_row5_col4, #T_329b3_row5_col5, #T_329b3_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_329b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_329b3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_329b3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_329b3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_329b3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_329b3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_329b3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_329b3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_329b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_329b3_row0_col0" class="data row0 col0" >0.7021</td>
#       <td id="T_329b3_row0_col1" class="data row0 col1" >0.7574</td>
#       <td id="T_329b3_row0_col2" class="data row0 col2" >0.8148</td>
#       <td id="T_329b3_row0_col3" class="data row0 col3" >0.7097</td>
#       <td id="T_329b3_row0_col4" class="data row0 col4" >0.7586</td>
#       <td id="T_329b3_row0_col5" class="data row0 col5" >0.3745</td>
#       <td id="T_329b3_row0_col6" class="data row0 col6" >0.3807</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_329b3_row1_col0" class="data row1 col0" >0.7447</td>
#       <td id="T_329b3_row1_col1" class="data row1 col1" >0.7552</td>
#       <td id="T_329b3_row1_col2" class="data row1 col2" >0.8272</td>
#       <td id="T_329b3_row1_col3" class="data row1 col3" >0.7528</td>
#       <td id="T_329b3_row1_col4" class="data row1 col4" >0.7882</td>
#       <td id="T_329b3_row1_col5" class="data row1 col5" >0.4686</td>
#       <td id="T_329b3_row1_col6" class="data row1 col6" >0.4719</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_329b3_row2_col0" class="data row2 col0" >0.6879</td>
#       <td id="T_329b3_row2_col1" class="data row2 col1" >0.7311</td>
#       <td id="T_329b3_row2_col2" class="data row2 col2" >0.7654</td>
#       <td id="T_329b3_row2_col3" class="data row2 col3" >0.7126</td>
#       <td id="T_329b3_row2_col4" class="data row2 col4" >0.7381</td>
#       <td id="T_329b3_row2_col5" class="data row2 col5" >0.3533</td>
#       <td id="T_329b3_row2_col6" class="data row2 col6" >0.3547</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_329b3_row3_col0" class="data row3 col0" >0.7447</td>
#       <td id="T_329b3_row3_col1" class="data row3 col1" >0.8045</td>
#       <td id="T_329b3_row3_col2" class="data row3 col2" >0.8659</td>
#       <td id="T_329b3_row3_col3" class="data row3 col3" >0.7396</td>
#       <td id="T_329b3_row3_col4" class="data row3 col4" >0.7978</td>
#       <td id="T_329b3_row3_col5" class="data row3 col5" >0.4573</td>
#       <td id="T_329b3_row3_col6" class="data row3 col6" >0.4679</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_329b3_row4_col0" class="data row4 col0" >0.6857</td>
#       <td id="T_329b3_row4_col1" class="data row4 col1" >0.7171</td>
#       <td id="T_329b3_row4_col2" class="data row4 col2" >0.8025</td>
#       <td id="T_329b3_row4_col3" class="data row4 col3" >0.6989</td>
#       <td id="T_329b3_row4_col4" class="data row4 col4" >0.7471</td>
#       <td id="T_329b3_row4_col5" class="data row4 col5" >0.3372</td>
#       <td id="T_329b3_row4_col6" class="data row4 col6" >0.3429</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_329b3_row5_col0" class="data row5 col0" >0.7130</td>
#       <td id="T_329b3_row5_col1" class="data row5 col1" >0.7531</td>
#       <td id="T_329b3_row5_col2" class="data row5 col2" >0.8151</td>
#       <td id="T_329b3_row5_col3" class="data row5 col3" >0.7227</td>
#       <td id="T_329b3_row5_col4" class="data row5 col4" >0.7660</td>
#       <td id="T_329b3_row5_col5" class="data row5 col5" >0.3982</td>
#       <td id="T_329b3_row5_col6" class="data row5 col6" >0.4036</td>
#     </tr>
#     <tr>
#       <th id="T_329b3_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_329b3_row6_col0" class="data row6 col0" >0.0264</td>
#       <td id="T_329b3_row6_col1" class="data row6 col1" >0.0298</td>
#       <td id="T_329b3_row6_col2" class="data row6 col2" >0.0327</td>
#       <td id="T_329b3_row6_col3" class="data row6 col3" >0.0201</td>
#       <td id="T_329b3_row6_col4" class="data row6 col4" >0.0232</td>
#       <td id="T_329b3_row6_col5" class="data row6 col5" >0.0543</td>
#       <td id="T_329b3_row6_col6" class="data row6 col6" >0.0555</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_prediction = predict_model(cat,raw_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a33a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a33a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3a33a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3a33a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3a33a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3a33a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3a33a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3a33a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3a33a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a33a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a33a_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_3a33a_row0_col1" class="data row0 col1" >0.7330</td>
#       <td id="T_3a33a_row0_col2" class="data row0 col2" >0.7567</td>
#       <td id="T_3a33a_row0_col3" class="data row0 col3" >0.8286</td>
#       <td id="T_3a33a_row0_col4" class="data row0 col4" >0.7500</td>
#       <td id="T_3a33a_row0_col5" class="data row0 col5" >0.7873</td>
#       <td id="T_3a33a_row0_col6" class="data row0 col6" >0.4309</td>
#       <td id="T_3a33a_row0_col7" class="data row0 col7" >0.4348</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_fi = pd.DataFrame({'importance':cat.feature_importances_,'feature':list(features_train)})
df_fi.sort_values('importance',ascending=False)
# Out:
#      importance   feature
# 150    4.090060  MACCS150
# 154    3.992201  MACCS154
# 139    2.813700  MACCS139
# 133    2.641112  MACCS133
# 164    2.458627  MACCS164
# ..          ...       ...
# 6      0.000000    MACCS6
# 5      0.000000    MACCS5
# 4      0.000000    MACCS4
# 2      0.000000    MACCS2
# 166    0.000000  MACCS166
#
# [167 rows x 2 columns]

# %%
explainer = shap.Explainer(cat,)
shap_values = explainer.shap_values(test_prediction.iloc[:,:167])
shap_df = pd.DataFrame(shap_values)
shap_list = []
for i in list(range(0,167,1)):
#     print(i)
    influ = sum(np.abs(shap_df.iloc[:,i]))
    shap_list.append(influ)
df_shap = pd.DataFrame({'shap':shap_list,'feature':list(features_train)})
df_shap.sort_values('shap',ascending=False)
# Out:
#           shap   feature
# 150  38.039387  MACCS150
# 154  33.028072  MACCS154
# 139  25.902226  MACCS139
# 133  20.555394  MACCS133
# 164  19.524020  MACCS164
# ..         ...       ...
# 6     0.000000    MACCS6
# 5     0.000000    MACCS5
# 4     0.000000    MACCS4
# 2     0.000000    MACCS2
# 166   0.000000  MACCS166
#
# [167 rows x 2 columns]

# %%
plt.xticks(fontfamily = 'Arial', fontsize=16)
plt.yticks(fontfamily = 'Arial', fontsize=16)
plt.xlabel(' ', fontfamily = 'Arial', fontsize=16)
plt.ylabel(' ', fontfamily = 'Arial', fontsize=16)

fig = plt.gcf()
plt.grid()
shap.summary_plot(shap_values, test_prediction.iloc[:,:167], max_display=20)
# fig.savefig('MACCS_SHAP2.jpg',dpi=600,bbox_inches='tight')
plt.show()
